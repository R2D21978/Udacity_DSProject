# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %% [markdown]
# Loading Data

# %%
file = 'C:\\Users\\R44063\\OneDrive - E.ON\\_VSCode\\Projekt Udacity\\data\\raw\\PurchaseOrders.csv'
df = pd.read_csv(file, sep=';', encoding='utf-8') # Good Polish encoding

# %% [markdown]
# Display the DataFrame

# %%
df
# Out:
#        Purchasing Document  Item Req Delivery Date Delivery Date  \
# 0               4500093085    10        06.06.2025    06.06.2025
# 1               4500045759    10        31.12.2024    29.02.2024
# 2               4500091628    10        05.06.2025           NaN
# 3               4500045943    10        31.01.2024    23.01.2024
# 4               4500090106    10        14.05.2025           NaN
# ...                    ...   ...               ...           ...
# 28650           4500054156    30        07.05.2024    25.10.2024
# 28651           4500054156    10        07.05.2024    25.10.2024
# 28652           4500054156    20        07.05.2024    25.10.2024
# 28653           4500089337    10        31.12.2025           NaN
# 28654           4500093409    10        30.06.2025           NaN
#
#       Delivery Completed Requisitioner Created By  Supplier Material Group  \
# 0                    Yes        A72755     M89400  42513214        C492005
# ...

# %% [markdown]
# Creating a target variable - Delayed delivery

# %%
# Get today's date (without time)
today = pd.to_datetime('today').normalize()

# Condition 1: Planned delivery date was more than 2 days ago and the delivery has not yet happened
condition_1 = (df['Req Delivery Date'] + pd.Timedelta(days=2) < today) & (df['Delivery Date'].isna())

# Condition 2: Delivery occurred more than 2 days before the requested delivery date
condition_2 = df['Req Delivery Date'] > (df['Delivery Date'] + pd.Timedelta(days=2))

# Combine both conditions to flag delayed deliveries
df['Delayed delivery'] = np.where(condition_1 | condition_2, 1, 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 today = pd.to_datetime('today').normalize()
#       4 # Condition 1: Planned delivery date was more than 2 days ago and the delivery has not yet happened
# ----> 5 condition_1 = (df['Req Delivery Date'] + pd.Timedelta(days=2) < today) & (df['Delivery Date'].isna())
#       7 # Condition 2: Delivery occurred more than 2 days before the requested delivery date
#       8 condition_2 = df['Req Delivery Date'] > (df['Delivery Date'] + pd.Timedelta(days=2))
#
# File c:\Users\R44063\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# ...
